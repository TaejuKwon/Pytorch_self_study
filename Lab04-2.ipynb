# %%
import torch

# %% [markdown]
# #**Pytorch Dataset**

# %%
from torch.utils.data import Dataset

class CustomDataset(Dataset):
  def __init__(self):
    self.x_data = [[73, 80, 75],
                   [93, 88, 93],
                   [89, 91, 90],
                   [96, 98, 100],
                   [73, 66, 70]]
    self.y_data = [[152], [185], [180], [196], [142]]

  def __len__(self):
    return len(self.x_data)
  
  def __getitem__(self, idx):
    x = torch.FloatTensor(self.x_data[idx])
    y = torch.FloatTensor(self.y_data[idx])

    return x, y


dataset = CustomDataset()

# %% [markdown]
# #**PyTorch DataLoader**

# %%
from torch.utils.data import DataLoader

dataloader = DataLoader(
    dataset,
    batch_size = 2,     # 각 mini batch의 크기 / 통상적으로 2의 제곱수로 설정
    shuffle = True      # Epoch마다 데이터셋을 섞어서 모델이 데이터의 순서를 외우지 못하게 함. True를 권장
)

# %%
import torch.nn as nn

class MultivariateLinearRegressionModel(nn.Module):
  def __init__(self):
    super().__init__()
    self.linear = nn.Linear(3, 1)   # 입력 차원:3 , 출력 차원: 1

  def forward(self, x):     # hypothesis 계산은 forwar()에서
    return self.linear(x)

model = MultivariateLinearRegressionModel()
optimizer = torch.optim.SGD(model.parameters(), lr = 1e-5)

# %% [markdown]
# #**Full Code with Dataset and DataLoader**

# %%
import torch.nn.functional as F

nb_epochs = 20

for epoch in range(nb_epochs + 1):
  for batch_idx, samples in enumerate(dataloader):
    x_train, y_train = samples

    prediction = model(x_train)

    cost = F.mse_loss(prediction, y_train)

    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
      epoch, nb_epochs, batch_idx+1, len(dataloader), cost.item()
    ))
# Out:
# Epoch    0/20 Batch 1/3 Cost: 0.746441
# Epoch    0/20 Batch 2/3 Cost: 2.015229
# Epoch    0/20 Batch 3/3 Cost: 5.237782
# Epoch    1/20 Batch 1/3 Cost: 2.710186
# Epoch    1/20 Batch 2/3 Cost: 0.531430
# Epoch    1/20 Batch 3/3 Cost: 4.705449
# Epoch    2/20 Batch 1/3 Cost: 2.886014
# Epoch    2/20 Batch 2/3 Cost: 2.189453
# Epoch    2/20 Batch 3/3 Cost: 0.364378
# Epoch    3/20 Batch 1/3 Cost: 2.298058
# Epoch    3/20 Batch 2/3 Cost: 2.196450
# Epoch    3/20 Batch 3/3 Cost: 0.722536
# Epoch    4/20 Batch 1/3 Cost: 1.783001
# Epoch    4/20 Batch 2/3 Cost: 3.837173
# Epoch    4/20 Batch 3/3 Cost: 0.016456
# Epoch    5/20 Batch 1/3 Cost: 0.309248
# Epoch    5/20 Batch 2/3 Cost: 2.338216
# Epoch    5/20 Batch 3/3 Cost: 4.023962
# Epoch    6/20 Batch 1/3 Cost: 3.705976
# Epoch    6/20 Batch 2/3 Cost: 2.242103
# Epoch    6/20 Batch 3/3 Cost: 0.282973
# Epoch    7/20 Batch 1/3 Cost: 1.079049
# Epoch    7/20 Batch 2/3 Cost: 1.268111
# Epoch    7/20 Batch 3/3 Cost: 5.158879
# Epoch    8/20 Batch 1/3 Cost: 1.387147
# Epoch    8/20 Batch 2/3 Cost: 1.893266
# Epoch    8/20 Batch 3/3 Cost: 4.598556
# Epoch    9/20 Batch 1/3 Cost: 1.617300
# Epoch    9/20 Batch 2/3 Cost: 1.936231
# Epoch    9/20 Batch 3/3 Cost: 4.490240
# Epoch   10/20 Batch 1/3 Cost: 2.909130
# Epoch   10/20 Batch 2/3 Cost: 0.618820
# Epoch   10/20 Batch 3/3 Cost: 4.516403
# Epoch   11/20 Batch 1/3 Cost: 0.522394
# Epoch   11/20 Batch 2/3 Cost: 3.058227
# Epoch   11/20 Batch 3/3 Cost: 5.001505
# Epoch   12/20 Batch 1/3 Cost: 3.764950
# Epoch   12/20 Batch 2/3 Cost: 0.821413
# Epoch   12/20 Batch 3/3 Cost: 0.211536
# Epoch   13/20 Batch 1/3 Cost: 1.895538
# Epoch   13/20 Batch 2/3 Cost: 3.721968
# Epoch   13/20 Batch 3/3 Cost: 0.281546
# Epoch   14/20 Batch 1/3 Cost: 1.828156
# Epoch   14/20 Batch 2/3 Cost: 2.336013
# Epoch   14/20 Batch 3/3 Cost: 1.010955
# Epoch   15/20 Batch 1/3 Cost: 0.361883
# Epoch   15/20 Batch 2/3 Cost: 3.669307
# Epoch   15/20 Batch 3/3 Cost: 0.653898
# Epoch   16/20 Batch 1/3 Cost: 1.197016
# Epoch   16/20 Batch 2/3 Cost: 3.197934
# Epoch   16/20 Batch 3/3 Cost: 0.515593
# Epoch   17/20 Batch 1/3 Cost: 3.620120
# Epoch   17/20 Batch 2/3 Cost: 0.623368
# Epoch   17/20 Batch 3/3 Cost: 0.510282
# Epoch   18/20 Batch 1/3 Cost: 0.555052
# Epoch   18/20 Batch 2/3 Cost: 1.927659
# Epoch   18/20 Batch 3/3 Cost: 4.483000
# Epoch   19/20 Batch 1/3 Cost: 1.636068
# Epoch   19/20 Batch 2/3 Cost: 0.067199
# Epoch   19/20 Batch 3/3 Cost: 5.705316
# Epoch   20/20 Batch 1/3 Cost: 0.305025
# Epoch   20/20 Batch 2/3 Cost: 2.070649
# Epoch   20/20 Batch 3/3 Cost: 4.538221
